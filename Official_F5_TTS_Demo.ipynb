# %%
#@title Install F5-TTS and Restart Session

# !git clone https://github.com/SWivid/F5-TTS.git
# %cd /content/F5-TTS
# !pip install -r requirements.txt
# !pip install -r requirements_eval.txt
from IPython.display import clear_output
clear_output()
import time
time.sleep(5)
import os
os.kill(os.getpid(), 9)

# %%
# %cd /content/F5-TTS
# !python gradio_app.py --share
# Out:
# /content/F5-TTS
# 2024-10-19 15:50:39.294388: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-19 15:50:39.314763: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-19 15:50:39.320641: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-19 15:50:39.334865: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-19 15:50:40.917882: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using cuda device
# config.json: 100% 1.26k/1.26k [00:00<00:00, 10.5MB/s]
# model.safetensors: 100% 1.62G/1.62G [00:09<00:00, 175MB/s]
# generation_config.json: 100% 3.77k/3.77k [00:00<00:00, 29.9MB/s]
# tokenizer_config.json: 100% 283k/283k [00:00<00:00, 12.6MB/s]
# vocab.json: 100% 1.04M/1.04M [00:00<00:00, 8.45MB/s]
# tokenizer.json: 100% 2.71M/2.71M [00:00<00:00, 17.1MB/s]
# merges.txt: 100% 494k/494k [00:00<00:00, 2.53MB/s]
# normalizer.json: 100% 52.7k/52.7k [00:00<00:00, 201MB/s]
# added_tokens.json: 100% 34.6k/34.6k [00:00<00:00, 158MB/s]
# special_tokens_map.json: 100% 2.19k/2.19k [00:00<00:00, 21.2MB/s]
# preprocessor_config.json: 100% 340/340 [00:00<00:00, 2.64MB/s]
# config.yaml: 100% 461/461 [00:00<00:00, 3.45MB/s]
# pytorch_model.bin: 100% 54.4M/54.4M [00:00<00:00, 234MB/s]
# /usr/local/lib/python3.10/dist-packages/vocos/pretrained.py:70: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path, map_location="cpu")
# model_1200000.safetensors: 100% 1.35G/1.35G [00:07<00:00, 186MB/s]
# model_1200000.safetensors: 100% 1.33G/1.33G [00:08<00:00, 153MB/s]
# Starting app...
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://e06f852713c7d98858.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Wake up to reality! Nothing ever goes as planned in this world... The longer you live, the more you realize that pain, suffering, and futility are inevitable. Your hopes, dreams, and bonds... they’re all destined to fade.
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:496: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# You have passed task=transcribe, but also have set `forced_decoder_ids` to [[1, None], [2, 50360]] which creates a conflict. `forced_decoder_ids` will be ignored in favor of task=transcribe.
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.43.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ref_text Feel pain, accept pain, and know pain. Those who do not know pain will never understand true peace. I will never forget the pain that Yahiko suffered.
# gen_text 0 Wake up to reality! Nothing ever goes as planned in this world... The longer you live,
# gen_text 1 the more you realize that pain, suffering, and futility are inevitable. Your hopes, dreams,
# gen_text 2 and bonds... they’re all destined to fade.
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.711 seconds.
# Prefix dict has been built successfully.
# /usr/local/lib/python3.10/dist-packages/gradio/processing_utils.py:574: UserWarning: Trying to convert audio automatically from float64 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
# Do you believe that bonds, friendship, and hope will save you? That’s nothing but a fool’s dream... only meant to comfort the weak. True strength lies in understanding the truth of this world. It is filled with conflict, betrayal, and despair. To achieve true peace, you must first have control... control that can only come through absolute power
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:496: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# ref_text Feel pain, accept pain, and know pain. Those who do not know pain will never understand true peace. I will never forget the pain that Yahiko suffered.
# gen_text 0 Do you believe that bonds, friendship, and hope will save you?
# gen_text 1 That’s nothing but a fool’s dream... only meant to comfort the weak.
# gen_text 2 True strength lies in understanding the truth of this world. It is filled with conflict, betrayal,
# gen_text 3 and despair. To achieve true peace, you must first have control...
# gen_text 4 control that can only come through absolute power
# /usr/local/lib/python3.10/dist-packages/gradio/processing_utils.py:574: UserWarning: Trying to convert audio automatically from float64 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:496: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# ref_text My DMs are crazy guys. I could make a whole series of just Tyler's DMs. Because the bad ones are very bad. Like insane. Let me not say, but just know it's very insane. My DMs are hectic.
# gen_text 0 Hi everyone, I’m Tyla, the queen sexy! I’m so excited to share my journey with you as a singer. Music has always been my passion,
# gen_text 1 and it’s where I find my true voice. I love blending different genres, from pop and R&B to soul, to create a sound that’s uniquely mine.
# gen_text 2 Each song I write comes from my heart, drawing on my experiences and emotions. I believe music has the power to connect us,
# gen_text 3 and I strive to make every performance an unforgettable experience. It’s been an incredible ride so far,
# gen_text 4 and I’m grateful for the amazing support from my fans.
# /usr/local/lib/python3.10/dist-packages/gradio/processing_utils.py:574: UserWarning: Trying to convert audio automatically from float64 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
# Hey everyone, I’m Tykla! I want to share a special story about how I met my best friend, Magali, right here in Burkina Faso. It was a warm afternoon, and I was performing at a local festival. The energy was electric, and the crowd was so welcoming! After my set, I decided to explore the market nearby. That’s where I first spotted Magali. She was singing along to a street performer, her voice blending beautifully with the music. Intrigued, I walked over to join her. We struck up a conversation, and I was instantly drawn to her vibrant spirit and infectious laughter! As we chatted, I discovered that we shared a love for music and a passion for storytelling. We ended up spending the entire day together, exploring the market, trying delicious local foods, and sharing our dreams and aspirations. It felt like we had known each other for years!
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:496: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# ref_text My DMs are crazy guys. I could make a whole series of just Tyler's DMs. Because the bad ones are very bad. Like insane. Let me not say, but just know it's very insane. My DMs are hectic.
# gen_text 0 Hey everyone, I’m Tykla! I want to share a special story about how I met my best friend, Magali, right here in Burkina Faso. It was a warm afternoon,
# gen_text 1 and I was performing at a local festival. The energy was electric, and the crowd was so welcoming! After my set, I decided to explore the market nearby.
# gen_text 2 That’s where I first spotted Magali. She was singing along to a street performer, her voice blending beautifully with the music. Intrigued,
# gen_text 3 I walked over to join her. We struck up a conversation, and I was instantly drawn to her vibrant spirit and infectious laughter! As we chatted,
# gen_text 4 I discovered that we shared a love for music and a passion for storytelling. We ended up spending the entire day together, exploring the market,
# gen_text 5 trying delicious local foods, and sharing our dreams and aspirations. It felt like we had known each other for years!
# /usr/local/lib/python3.10/dist-packages/gradio/processing_utils.py:574: UserWarning: Trying to convert audio automatically from float64 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
# Je voulais absolument partager quelques-uns des messages et DMs les plus fous que j’ai reçus de mes fans—c’est vraiment incroyable ! L’autre jour, j’ai ouvert ma boîte de réception et j’ai trouvé un message d’un fan qui m’a dit que ma chanson l’avait aidé à traverser une période difficile. Il a même ajouté qu’il avait créé toute une chorégraphie sur ma chanson pour la présenter à son spectacle de talents à l’école ! J’étais tellement touchée ; je veux dire, c’est ça, la musique, non ?
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:496: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# ref_text My DMs are crazy guys. I could make a whole series of just Tyler's DMs. Because the bad ones are very bad. Like insane. Let me not say, but just know it's very insane. My DMs are hectic.
# gen_text 0 Je voulais absolument partager quelques-uns des messages et DMs les plus fous que j’ai reçus de mes fans—c’est vraiment incroyable !
# gen_text 1 L’autre jour,
# gen_text 2 j’ai ouvert ma boîte de réception et j’ai trouvé un message d’un fan qui m’a dit que ma chanson l’avait aidé à traverser une période difficile.
# gen_text 3 Il a même ajouté qu’il avait créé toute une chorégraphie sur ma chanson pour la présenter à son spectacle de talents à l’école !
# gen_text 4 J’étais tellement touchée ; je veux dire, c’est ça, la musique, non ?
# /usr/local/lib/python3.10/dist-packages/gradio/processing_utils.py:574: UserWarning: Trying to convert audio automatically from float64 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
